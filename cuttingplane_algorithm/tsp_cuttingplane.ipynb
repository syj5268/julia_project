# %%
using JuMP, Gurobi
using Random
using Plots

# %%
function generate_distance_matrix(n; random_seed = 1)
    rng = Random.MersenneTwister(random_seed)
    X = 100 * rand(rng, n) # x 좌표
    Y = 100 * rand(rng, n) # y 좌표
    d = [sqrt((X[i] - X[j])^2 + (Y[i] - Y[j])^2) for i in 1:n, j in 1:n] #distance
    return X, Y, d
end

n = 10
X, Y, d = generate_distance_matrix(n)
# Out:
# ([23.603334566204694, 34.651701419196044, 31.27069683360675, 0.790928339056074, 48.86128300795012, 21.096820215853597, 95.1916339835734, 99.99046588986135, 25.166218303197184, 98.66663668987997], [55.57510873245724, 43.71079746096251, 42.471785049513144, 77.3223048457377, 28.11902322857298, 20.947237319807076, 25.137920979222493, 2.037486871266725, 28.77015122756894, 85.9512136087661], [0.0 16.21197989343667 … 26.850481418667766 80.97658348662696; 16.21197989343667 0.0 … 17.697381156976782 76.69527165379544; … ; 26.850481418667766 17.697381156976782 … 0.0 93.12349541366977; 80.97658348662696 76.69527165379544 … 93.12349541366977 0.0])

# %%
function build_tsp_model(d, n)
    model = Model(Gurobi.Optimizer)
    @variable(model, x[1:n, 1:n], Bin, Symmetric)
    @objective(model, Min, sum(d .* x) / 2)
    @constraint(model, [i in 1:n], sum(x[i, :]) == 2)
    @constraint(model, [i in 1:n], x[i, i] == 0)
    return model
end
# Out:
# build_tsp_model (generic function with 1 method)

# %%
iterative_model = build_tsp_model(d, n)
optimize!(iterative_model)
time_iterated = solve_time(iterative_model)
#cycle = subtour(iterative_model[:x])
#while 1 < length(cycle) < n
    #println("Found cycle of length $(length(cycle))")
    #S = [(i, j) for (i, j) in Iterators.product(cycle, cycle) if i < j]
    #@constraint(
    #    iterative_model,
    #    sum(iterative_model[:x][i, j] for (i, j) in S) <= length(cycle) - 1,
    #)
    optimize!(iterative_model)
    global time_iterated += solve_time(iterative_model)
    #global cycle = subtour(iterative_model[:x])
end

objective_value(iterative_model)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-21
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: AMD Ryzen 9 5900X 12-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 20 rows, 55 columns and 110 nonzeros
# Model fingerprint: 0x414e3370
# Variable types: 0 continuous, 55 integer (55 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective 439.4661225
# Presolve removed 10 rows and 10 columns
# Presolve time: 0.00s
# Presolved: 10 rows, 45 columns, 90 nonzeros
# Variable types: 0 continuous, 45 integer (45 binary)
#
# Root relaxation: objective 3.272571e+02, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     327.2571314  327.25713  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 327.257 439.466
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.272571314388e+02, best bound 3.272571314388e+02, gap 0.0000%
#
# User-callback calls 150, time in user-callback 0.00 sec
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: AMD Ryzen 9 5900X 12-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 20 rows, 55 columns and 110 nonzeros
# Model fingerprint: 0x414e3370
# Variable types: 0 continuous, 55 integer (55 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 2e+00]
# Presolved: 10 rows, 45 columns, 90 nonzeros
#
# Continuing optimization...
#
#
# Explored 1 nodes (13 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 327.257 439.466
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.272571314388e+02, best bound 3.272571314388e+02, gap 0.0000%
#
# User-callback calls 27, time in user-callback 0.00 sec
# syntax: unexpected "end"
#
# Stacktrace:
#  [1] top-level scope
#    @ In[6]:15

# %%
iterative_model = build_tsp_model(d, n)
optimize!(iterative_model)
time_iterated = solve_time(iterative_model)

# Check for fractional solutions and add Gomory cuts
fractional_solutions = [(i, j) for i in 1:n, j in 1:n if abs(value(x[i, j]) - round(value(x[i, j]))) > 1e-6]
if length(fractional_solutions) > 0
    println("\nFractional Solutions Found, Adding Gomory Cuts:")
    for (i, j) in fractional_solutions
        @constraint(model, x[i, j] == 0)
        optimize!(model)
        println("Cut added for x[$i, $j]")
    end
end

# Solve the MILP problem
optimize!(model)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-21
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: AMD Ryzen 9 5900X 12-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Optimize a model with 20 rows, 55 columns and 110 nonzeros
# Model fingerprint: 0x414e3370
# Variable types: 0 continuous, 55 integer (55 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective 439.4661225
# Presolve removed 10 rows and 10 columns
# Presolve time: 0.00s
# Presolved: 10 rows, 45 columns, 90 nonzeros
# Variable types: 0 continuous, 45 integer (45 binary)
#
# Root relaxation: objective 3.272571e+02, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     327.2571314  327.25713  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 327.257 439.466
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.272571314388e+02, best bound 3.272571314388e+02, gap 0.0000%
#
# User-callback calls 150, time in user-callback 0.00 sec
# UndefVarError: `x` not defined
#
# Stacktrace:
#  [1] (::var"#31#33")(::Tuple{Int64, Int64})
#    @ Main ./none:0
#  [2] iterate(::Base.Iterators.Filter{var"#31#33", Base.Iterators.ProductIterator{Tuple{UnitRange{Int64}, UnitRange{Int64}}}})
#    @ Base.Iterators ./iterators.jl:514
#  [3] iterate
#    @ ./generator.jl:44 [inlined]
#  [4] grow_to!
#    @ ./array.jl:855 [inlined]
#  [5] collect(itr::Base.Generator{Base.Iterators.Filter{var"#31#33", Base.Iterators.ProductIterator{Tuple{UnitRange{Int64}, UnitRange{Int64}}}}, var"#30#32"})
#    @ Base ./array.jl:779
#  [6] top-level scope
#    @ In[10]:6

# %%
function selected_edges(x::Matrix{Float64}, n)
    return Tuple{Int,Int}[(i, j) for i in 1:n, j in 1:n if x[i, j] > 0.5]
end
# Out:
# selected_edges (generic function with 1 method)

# %%
using Pkg
Pkg.add("TrafficAssignment")

using TrafficAssignment

# 네트워크 정보
i_nodes = [1, 2, 2, 4]
t_nodes = [2, 3, 4, 3]
capacities = [100.0, 50.0, 100.0, 100.0]
free_flow_times = [10.0, 10.0, 100.0, 100.0]
ds_balances = [0.0, 50.0, 50.0, 50.0]

l_lengths = [0.0, 50.0, 50.0, 50.0]
power_factors = [1.0, 1.0, 1.0, 1.0]
speed_limits = [100.0, 100.0, 100.0, 100.0]
toll_costs = [0.0, 0.0, 0.0, 0.0]
l_types = [1, 1, 1, 1]

# 수요 정보
travel_demands = zeros(4, 4)
travel_demands[1, 3] = 60
travel_demands[1, 4] = 40
origin_destination_pairs = [(1, 3), (1, 4)]

# TA_Data 인스턴스
ta_data = TA_Data(
    "Problem1",  # network_name
    3,  # number_of_zones
    4,  # number_of_nodes
    1,  # first_thru_node
    4,  # number_of_links
    i_nodes,
    t_nodes,
    capacities,
    l_lengths,
    free_flow_times,
    ds_balances,
    power_factors,
    speed_limits,
    toll_costs,
    l_types,
    sum(travel_demands),  # total_od_flow
    travel_demands,
    origin_destination_pairs,
    0.5,  # toll_factor
    0.5,  # distance_factor
    Inf  # best_objective
)

link_flow, link_travel_time, objective =
ta_frank_wolfe(ta_data, method=:cfw, max_iter_no=1000, step=:newton, log=:on, tol=1e-5)

print("Link flow: ", link_flow, "\n")
print("Link travel time: ", link_travel_time, "\n")
print("Objective: ", objective, "\n")

using LinearAlgebra
system_travel_time = dot(link_travel_time, link_flow)

print("System travel time: ", system_travel_time, "\n")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed Calculus ─────────────── v0.5.1
#    Installed JpegTurbo_jll ────────── v3.0.1+0
#    Installed URIParser ────────────── v0.4.1
#    Installed PlotUtils ────────────── v1.2.0
#    Installed InvertedIndices ──────── v1.3.0
#    Installed Unitful ──────────────── v1.19.0
#    Installed MutableArithmetics ───── v1.4.0
#    Installed StaticArrays ─────────── v0.12.6
#    Installed HTTP ─────────────────── v1.10.1
#    Installed DataFrames ───────────── v0.20.2
#    Installed BinDeps ──────────────── v1.0.2
#    Installed XZ_jll ───────────────── v5.4.5+0
#    Installed fzf_jll ──────────────── v0.43.0+0
#    Installed Missings ─────────────── v0.4.5
#    Installed TrafficAssignment ────── v0.6.3
#    Installed NaNMath ──────────────── v0.3.7
#    Installed BenchmarkTools ───────── v1.4.0
#    Installed NLSolversBase ────────── v7.5.0
#    Installed libpng_jll ───────────── v1.6.40+0
#    Installed Compat ───────────────── v3.47.0
#    Installed JLFzf ────────────────── v0.1.7
#    Installed MbedTLS ──────────────── v1.1.9
#    Installed PositiveFactorizations ─ v0.2.4
#    Installed Conda ────────────────── v1.10.0
#    Installed StatsBase ────────────── v0.33.21
#    Installed MathOptInterface ─────── v1.23.0
#    Installed DiffEqDiffTools ──────── v1.7.0
#    Installed Parsers ──────────────── v2.8.0
#    Installed PooledArrays ─────────── v0.5.3
#    Installed Reexport ─────────────── v0.2.0
#    Installed ArrayInterface ───────── v2.14.17
#    Installed OrderedCollections ───── v1.6.3
#    Installed CategoricalArrays ────── v0.7.7
#    Installed LineSearches ─────────── v7.1.1
#    Installed UnPack ───────────────── v1.0.2
#    Installed XML2_jll ─────────────── v2.12.2+0
#    Installed BitFlags ─────────────── v0.1.8
#    Installed SortingAlgorithms ────── v0.3.2
#    Installed FillArrays ───────────── v0.8.14
#    Installed Parameters ───────────── v0.12.3
#    Installed Optim ────────────────── v0.21.0
#     Updating `~/.julia/environments/v1.9/Project.toml`
#   [735ffce8] + TrafficAssignment v0.6.3
#     Updating `~/.julia/environments/v1.9/Manifest.toml`
# ⌅ [4fba245c] + ArrayInterface v2.14.17
#   [6e4b80f9] ↑ BenchmarkTools v1.3.2 ⇒ v1.4.0
#   [9e28174c] + BinDeps v1.0.2
#   [d1d4a3ce] ↑ BitFlags v0.1.7 ⇒ v0.1.8
#   [49dc2e85] + Calculus v0.5.1
# ⌅ [324d7699] + CategoricalArrays v0.7.7
# ⌅ [34da2185] ↓ Compat v4.10.0 ⇒ v3.47.0
#   [8f4d0f93] ↑ Conda v1.9.1 ⇒ v1.10.0
# ⌅ [a93c6f00] + DataFrames v0.20.2
#   [01453d9d] + DiffEqDiffTools v1.7.0
# ⌅ [1a297f60] + FillArrays v0.8.14
#   [cd3eb016] ↑ HTTP v1.10.0 ⇒ v1.10.1
#   [41ab1584] + InvertedIndices v1.3.0
#   [1019f520] ↑ JLFzf v0.1.6 ⇒ v0.1.7
# ⌃ [d3d80556] + LineSearches v7.1.1
#   [b8f27783] ↑ MathOptInterface v1.22.0 ⇒ v1.23.0
#   [739be429] ↑ MbedTLS v1.1.7 ⇒ v1.1.9
# ⌅ [e1d29d7a] ↓ Missings v1.1.0 ⇒ v0.4.5
#   [d8a4904e] ↑ MutableArithmetics v1.3.3 ⇒ v1.4.0
# ⌅ [d41bc354] + NLSolversBase v7.5.0
# ⌅ [77ba4419] ↓ NaNMath v1.0.2 ⇒ v0.3.7
# ⌅ [429524aa] + Optim v0.21.0
#   [bac558e1] ↑ OrderedCollections v1.6.2 ⇒ v1.6.3
#   [d96e819e] + Parameters v0.12.3
#   [69de0a69] ↑ Parsers v2.7.2 ⇒ v2.8.0
# ⌃ [995b91a9] ↓ PlotUtils v1.3.5 ⇒ v1.2.0
# ⌅ [2dfb63ee] ↓ PooledArrays v1.4.3 ⇒ v0.5.3
#   [85a6dd25] + PositiveFactorizations v0.2.4
# ⌅ [189a3867] ↓ Reexport v1.2.2 ⇒ v0.2.0
# ⌅ [a2af1166] ↓ SortingAlgorithms v1.2.0 ⇒ v0.3.2
# ⌅ [90137ffa] ↓ StaticArrays v1.6.5 ⇒ v0.12.6
# ⌅ [2913bbd2] ↓ StatsBase v0.34.2 ⇒ v0.33.21
#   [735ffce8] + TrafficAssignment v0.6.3
#   [30578b45] + URIParser v0.4.1
#   [3a884ed6] + UnPack v1.0.2
#   [1986cc42] ↑ Unitful v1.17.0 ⇒ v1.19.0
#   [aacddb02] ↑ JpegTurbo_jll v2.1.91+0 ⇒ v3.0.1+0
#   [02c8fc9c] ↑ XML2_jll v2.11.5+0 ⇒ v2.12.2+0
#   [ffd25f8a] ↑ XZ_jll v5.4.4+0 ⇒ v5.4.5+0
#   [214eeab7] ↑ fzf_jll v0.35.1+0 ⇒ v0.43.0+0
#   [b53b4c65] ↑ libpng_jll v1.6.38+0 ⇒ v1.6.40+0
#         Info Packages marked with ⌃ and ⌅ have new versions available, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
#     Building Conda → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/51cab8e982c5b598eea9c8ceaced4b58d9dd37c9/build.log`
# Precompiling project...
#   ✓ Reexport
#   ✓ InvertedIndices
#   ✓ PositiveFactorizations
#   ✓ UnPack
#   ✓ BitFlags
#   ✓ NaNMath
#   ✓ Missings
#   ✓ OrderedCollections
#   ✓ FillArrays
#   ✓ URIParser
#   ✓ Calculus
#   ✓ libpng_jll
#   ✓ MbedTLS
#   ✓ PooledArrays
#   ✓ fzf_jll
#   ✓ ArrayInterface
#   ✓ XZ_jll
#   ✓ JpegTurbo_jll
#   ✓ XML2_jll
#   ✓ DiffRules
#   ✓ Compat
#   ✓ Parameters
#   ✓ Libtiff_jll
#   ✓ JLFzf
#   ✓ Gettext_jll
#   ✓ Wayland_jll
#   ✓ Tables
#   ✓ XSLT_jll
#   ✓ BinDeps
#   ✓ Glib_jll
#   ✓ OpenSSL
#   ✓ Xorg_libxcb_jll
#   ✓ FilePathsBase
#   ✓ StaticArrays
#   ✓ Xorg_xcb_util_jll
#   ✓ Xorg_libX11_jll
#   ✓ DataStructures
#   ✓ Latexify
#   ✓ Xorg_xcb_util_image_jll
#   ✓ Xorg_xcb_util_wm_jll
#   ✓ Xorg_libXrender_jll
#   ✓ Xorg_xcb_util_keysyms_jll
#   ✓ Xorg_xcb_util_renderutil_jll
#   ✓ Xorg_libXext_jll
#   ✓ Xorg_libxkbfile_jll
#   ✓ Xorg_libXfixes_jll
#   ✓ SortingAlgorithms
#   ✓ ArnoldiMethod
#   ✓ DiffEqDiffTools
#   ✓ Xorg_xcb_util_cursor_jll
#   ✓ Xorg_xkbcomp_jll
#   ✓ Xorg_libXrandr_jll
#   ✓ Xorg_libXinerama_jll
#   ✓ Libglvnd_jll
#   ✓ Cairo_jll
#   ✓ Xorg_libXi_jll
#   ✓ Xorg_libXcursor_jll
#   ✓ ForwardDiff
#   ✓ Xorg_xkeyboard_config_jll
#   ✓ HarfBuzz_jll
#   ✓ HTTP
#   ✓ GLFW_jll
#   ✓ xkbcommon_jll
#   ✓ libass_jll
#   ✓ ForwardDiff → ForwardDiffStaticArraysExt
#   ✓ Colors
#   ✓ MutableArithmetics
#   ✓ StatsBase
#   ✓ Vulkan_Loader_jll
#   ✓ FFMPEG_jll
#   ✓ Qt6Base_jll
#   ✓ FFMPEG
#   ✓ NLSolversBase
#   ✓ GR_jll
#   ✓ LightGraphs
#   ✓ Graphs
#   ✓ LineSearches
#   ✓ SimpleWeightedGraphs
#   ✓ Optim
#   ✓ ColorSchemes
#   ✓ PlotUtils
#   ✓ PlotThemes
#   ✓ RecipesPipeline
#   ✓ Parsers
#   ✓ InlineStrings
#   ✓ WeakRefStrings
#   ✓ JSON
#   ✓ Conda
#   ✓ BenchmarkTools
#   ✓ CategoricalArrays
#   ✓ Compose
#   ✓ IJulia
#   ✓ GR
#   ✓ GraphPlot
#   ✓ DataFrames
#   ✓ Latexify → DataFramesExt
#   ✓ Unitful
#   ✓ TrafficAssignment
#   ✓ UnitfulLatexify
#   ✓ CSV
#   ✓ Plots
#   ✓ Plots → IJuliaExt
#   ✓ Plots → UnitfulExt
#   ✓ MathOptInterface
#   ✓ Gurobi
#   ✓ CPLEX
#   ✓ GLPK
#   ✓ JuMP
#   108 dependencies successfully precompiled in 103 seconds. 106 already precompiled.
#   5 dependencies precompiled but different versions are currently loaded. Restart julia to access the new versions
#   3 dependencies had warnings during precompilation:
# ┌ NLSolversBase [d41bc354-129a-5804-8e4c-c37616107c6c]
# │  WARNING: method definition for TwiceDifferentiable at /home/yoonju/.julia/packages/NLSolversBase/NsXIC/src/objective_types/incomplete.jl:86 declares type variable TH but does not use it.
# │  WARNING: method definition for TwiceDifferentiable at /home/yoonju/.julia/packages/NLSolversBase/NsXIC/src/objective_types/incomplete.jl:94 declares type variable TH but does not use it.
# └
# ┌ CategoricalArrays [324d7699-5711-5eae-9e2f-1d82baa6b597]
# │  WARNING: method definition for catvaluetype at /home/yoonju/.julia/packages/CategoricalArrays/dmrjI/src/value.jl:48 declares type variable R but does not use it.
# └
# ┌ DiffEqDiffTools [01453d9d-ee7c-5054-8395-0335cb756afa]
# │  WARNING: method definition for #finite_difference_jacobian#27 at /home/yoonju/.julia/packages/DiffEqDiffTools/3mm8U/src/jacobians.jl:117 declares type variable T3 but does not use it.
# └
# [ Info: Precompiling TrafficAssignment [735ffce8-66c7-5b61-a90f-89c46d1a79d5]
# ┌ Warning: Module JSON with build ID fafbfcfd-3efa-8e43-0000-02848975c5f3 is missing from the cache.
# │ This may mean JSON [682c06a0-de6a-54ab-a142-c8b1cf79cde6] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1793
# [ Info: Skipping precompilation since __precompile__(false). Importing TrafficAssignment [735ffce8-66c7-5b61-a90f-89c46d1a79d5].
# [ Info: Precompiling DataFrames [a93c6f00-e57d-5684-b7b6-d8193f3e46c0]
# ┌ Warning: Module JSON with build ID fafbfcfd-3efa-8e43-0000-02848975c5f3 is missing from the cache.
# │ This may mean JSON [682c06a0-de6a-54ab-a142-c8b1cf79cde6] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1793
# [ Info: Skipping precompilation since __precompile__(false). Importing DataFrames [a93c6f00-e57d-5684-b7b6-d8193f3e46c0].
# [ Info: Precompiling CategoricalArrays [324d7699-5711-5eae-9e2f-1d82baa6b597]
# ┌ Warning: Module JSON with build ID fafbfcfd-3efa-8e43-0000-02848975c5f3 is missing from the cache.
# │ This may mean JSON [682c06a0-de6a-54ab-a142-c8b1cf79cde6] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1793
# [ Info: Skipping precompilation since __precompile__(false). Importing CategoricalArrays [324d7699-5711-5eae-9e2f-1d82baa6b597].
# WARNING: method definition for catvaluetype at /home/yoonju/.julia/packages/CategoricalArrays/dmrjI/src/value.jl:48 declares type variable R but does not use it.
# -------------------------------------
# Network Name: Problem1
# Method: cfw
# Line Search Step: newton
# Maximum Interation Number: 1000
# Tolerance for AEC: 1.0e-5
# Number of processors: 1
# Setup time = 0.09076380729675293 seconds
# k=   1, tauk=            NaN, objective=   63675.000000, aec=   0.0000000000
# Iteration time = 0.2001039981842041 seconds
# Link flow: [100.0, 60.0, 40.0, 0.0]
# Link travel time: [10.0, 635.0, 2125.0, 125.0]
# Objective: 63675.0
# System travel time: 124100.0
